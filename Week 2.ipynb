# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 1: Open the file in your python notebook, print first 5 rows of the dataset and mention what are the dependent and independent variables in the Data.

# %%
bCancer  = pd.read_csv(r"/Users/ranjithtalamanchi/Downloads/Breast-Cancer-Detection-using-Machine-Learning-master/Breast_Cancer_Wisconsin.csv")
bCancer.head()
# diagnosis is dependent and remaining all are independent varibles
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Step 2: Find the statistical parameters of the Data that you have

# %%
bCancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# # Step 3: Find the shape of the Dataset in hand.

# %%
df = bCancer.iloc[:,:32] # i removed id(1st) and  unnamed (last column)  
df.shape
# Out:
# (569, 32)

# %% [markdown]
# # Step 4: Find missing values from the Dataset

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# # Step 5: Find the value count of B(Benign) and M(Malignant) cancer cells in the column "diagnosis"

# %%
df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_Y=LabelEncoder()
df.iloc[:,1]=labelencoder_Y.fit_transform(df.iloc[:,1].values)
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Step 6: Creating a pairplot and mention the findings

# %%
sns.pairplot(df.iloc[:,:5])

# %% [markdown]
# 1. Diagnosis column againest all the column clarly dividing Benign and Malignant
# 2. perimeter_mean and radious_mean are have same value(quantity)(we can see a clear line)

# %% [markdown]
# # Step 7: Create a correlation matrix and mention strongly, weakly and negatively correlated quantities.

# %%
df.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %% [markdown]
# Correlation is vice versa if a -> b x% then b-> a also x%
# 1. All means are  strongly correlated with  their respictive worst varibles
# 2. radious_mean,area_worst , peremeter_worst , radious_worst , area_mean , perimeter_mean  is having more than 90% with each other (Strongly correlated)
# 3. texture_se is 50% negatively correlated(weakly) and 50% weakly correlated with other varibles
# 4. Texture_mean in weakly correlated with almost all the varibles
# 5. fractal_dimension_mean , smoothness_se,symmetry_se are negatively correlated(weakly) 40% of the varibles

# %% [markdown]
# # Step 8: Create a heatmap of the correlated features (helps in visualization)

# %%
plt.figure(figsize=(17,15))
sns.heatmap(df.corr(),annot=True,fmt="0.0%")
